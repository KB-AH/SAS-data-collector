# %%
import torch
import onnx

model = onnx.load("./test_model.onnx")
onnx.checker.check_model(model)

# %%
model
# Out:
# ir_version: 8
# producer_name: "skl2onnx"
# producer_version: "1.12"
# domain: "ai.onnx"
# model_version: 0
# doc_string: ""
# graph {
#   node {
#     input: "int_input"
#     output: "label"
#     output: "probability_tensor"
#     name: "LinearClassifier"
#     op_type: "LinearClassifier"
#     attribute {
#       name: "classlabels_ints"
#       ints: 0
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "coefficients"
#       floats: -0.09904298186302185
#       floats: 0.10720745474100113
#       floats: 0.11179780215024948
#       floats: 0.008597534149885178
#       floats: -0.023450687527656555
#       floats: 0.024701572954654694
#       floats: 0.007360843010246754
#       floats: 0.11914403736591339
#       floats: -0.026357145980000496
#       floats: -0.026835929602384567
#       floats: -0.05952392518520355
#       floats: 0.15822631120681763
#       floats: -0.0006301335524767637
#       floats: 0.2853241562843323
# ...
